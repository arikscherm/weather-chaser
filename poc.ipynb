# %%
# TODO:
# Get data for Lower 48. See if another language will help us get data faster
# Put make_buffer, weather api calls and folium map in python module
# See if we can use mapclassify to color the pins

# %%
import folium
from folium.plugins import MarkerCluster
import numpy as np


# Bounding box around area of interest. Do entire lower 48 when you have time to run it. 
# Faster language might be ideal for this part? Timer?
west = -114.7
east = -102.3
north = 45.1
south = 33.1

# Resolution of grid of points
num_lat_points = 30
num_lon_points = 30

# Generate latitude and longitude points
latitudes = np.linspace(south, north, num_lat_points)
longitudes = np.linspace(west, east, num_lon_points)

m = folium.Map(location=[(north+south)/2,(east+west)/2], zoom_start=6)
cluster = MarkerCluster().add_to(m)

# Add generated coordinate pairs to cluster layer
for lat in latitudes:
    for lon in longitudes:
        folium.Marker([lat, lon]).add_to(cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8afb2698c4e7d97d2c9459078f446b15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8afb2698c4e7d97d2c9459078f446b15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8afb2698c4e7d97d2c9459078f446b15 = L.map(
#                 &quot;map_8afb2698c4e7d97d2c9459078f446b15&quot;,
#                 {
#                     center: [39.1, -108.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_081f4a924bc796cf99e0a589105ab7ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_081f4a924bc796cf99e0a589105ab7ad.addTo(map_8afb2698c4e7d97d2c9459078f446b15);
#
#
#             var marker_cluster_3666b6a0e592d66ade73fcf9468d93da = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_158291cce5e8aa24a88d1ca9d9e08759 = L.marker(
#                 [33.1, -114.7],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_7926559f7f4b26a25f46407a6cbfa5eb = L.marker(
#                 [33.1, -114.27241379310345],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_2c9d38153862cef59b69bf7d22a7fe0b = L.marker(
#                 [33.1, -113.8448275862069],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_101d486eea2abd03f19671047ae44098 = L.marker(
#                 [33.1, -113.41724137931034],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_26f92eadf0cfde726f66fad7281f14d5 = L.marker(
#                 [33.1, -112.98965517241379],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_b50b9b5c2d31868bcffb3c5f603a0b16 = L.marker(
#                 [33.1, -112.56206896551724],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_ca6f6180be83b010ce46e3daa788fe1d = L.marker(
#                 [33.1, -112.13448275862069],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_b415ce2e2a5e907130c203589d966a6d = L.marker(
#                 [33.1, -111.70689655172414],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_78f8d111e03bf037dc876cc954d87475 = L.marker(
#                 [33.1, -111.27931034482759],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_a39693eab20a511aebf7e6bb560424ff = L.marker(
#                 [33.1, -110.85172413793103],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_cf66137d73baae112860573d6b316c32 = L.marker(
#                 [33.1, -110.42413793103448],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_ab0f5a7e1236b8b66ae101c06d1deaee = L.marker(
#                 [33.1, -109.99655172413793],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_d0eddbf65fcc324737b9711b9fa8a9e7 = L.marker(
#                 [33.1, -109.56896551724138],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_b32c7d9e939d5234a438ef64dbbc62a5 = L.marker(
#                 [33.1, -109.14137931034483],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_7ec6d4baebaebe111ee8be79b9d03084 = L.marker(
#                 [33.1, -108.71379310344828],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_ade92833c493d4f7a49bef98876e10e3 = L.marker(
#                 [33.1, -108.28620689655172],
#                 {}
#             ).addTo(marker_cluster_3666b6a0e592d66ade73fcf9468d93da);
#
#
#             var marker_fb38cb2f3297f59088d47b167c130716 = L.marker(
#                 [33.1, -107.85862068965517],
#                 {}

# %%
import geopandas as gpd
import requests
from shapely.geometry import Point

num_requests = 0

office_data = {
    'geometry' : [],
    'grid_x' : [],
    'grid_y' : [],
    'grid_id' : [],
    'original_point' : []
}
for lat in latitudes:
    for lng in longitudes:
        num_requests += 1
        print(f"{num_requests} requests made")
        response = requests.get(f'https://api.weather.gov/points/{lat},{lng}')
        if response.status_code != 200: print("unable to retrieve observation data")
        else:
            response_json = response.json()
            properties = response_json['properties']
            office_data['geometry'].append(Point(properties['relativeLocation']['geometry']['coordinates']))
            office_data['grid_x'].append(properties['gridX'])
            office_data['grid_y'].append(properties['gridY'])
            office_data['grid_id'].append(properties['gridId'])
            office_data['original_point'].append((lat,lng))
# Out:
# 1 requests made
# 2 requests made
# 3 requests made
# 4 requests made
# 5 requests made
# 6 requests made
# 7 requests made
# 8 requests made
# 9 requests made
# 10 requests made
# 11 requests made
# 12 requests made
# 13 requests made
# 14 requests made
# 15 requests made
# 16 requests made
# 17 requests made
# 18 requests made
# 19 requests made
# 20 requests made
# 21 requests made
# 22 requests made
# 23 requests made
# 24 requests made
# 25 requests made
# 26 requests made
# 27 requests made
# 28 requests made
# 29 requests made
# 30 requests made
# 31 requests made
# 32 requests made
# 33 requests made
# 34 requests made
# 35 requests made
# 36 requests made
# 37 requests made
# 38 requests made
# 39 requests made
# 40 requests made
# 41 requests made
# 42 requests made
# 43 requests made
# 44 requests made
# 45 requests made
# 46 requests made
# 47 requests made
# 48 requests made
# 49 requests made
# 50 requests made
# 51 requests made
# 52 requests made
# 53 requests made
# 54 requests made
# 55 requests made
# 56 requests made
# 57 requests made
# 58 requests made
# 59 requests made
# 60 requests made
# 61 requests made
# 62 requests made
# 63 requests made
# 64 requests made
# 65 requests made
# unable to retrieve observation data
# 66 requests made
# 67 requests made
# 68 requests made
# 69 requests made
# 70 requests made
# 71 requests made
# 72 requests made
# 73 requests made
# 74 requests made
# 75 requests made
# 76 requests made
# 77 requests made
# 78 requests made
# 79 requests made
# 80 requests made
# 81 requests made
# 82 requests made
# 83 requests made
# 84 requests made
# 85 requests made
# 86 requests made
# 87 requests made
# 88 requests made
# 89 requests made
# 90 requests made
# 91 requests made
# 92 requests made
# 93 requests made
# 94 requests made
# 95 requests made
# unable to retrieve observation data
# 96 requests made
# 97 requests made
# 98 requests made
# 99 requests made
# 100 requests made
# 101 requests made
# 102 requests made
# 103 requests made
# 104 requests made
# 105 requests made
# 106 requests made
# 107 requests made
# 108 requests made
# 109 requests made
# 110 requests made
# 111 requests made
# 112 requests made
# 113 requests made
# 114 requests made
# 115 requests made
# 116 requests made
# 117 requests made
# 118 requests made
# 119 requests made
# 120 requests made
# 121 requests made
# 122 requests made
# 123 requests made
# 124 requests made
# 125 requests made
# 126 requests made
# 127 requests made
# 128 requests made
# 129 requests made
# 130 requests made
# 131 requests made
# 132 requests made
# 133 requests made
# 134 requests made
# 135 requests made
# 136 requests made
# 137 requests made
# 138 requests made
# 139 requests made
# 140 requests made
# 141 requests made
# 142 requests made
# 143 requests made
# 144 requests made
# 145 requests made
# 146 requests made
# 147 requests made
# 148 requests made
# 149 requests made
# 150 requests made
# 151 requests made
# 152 requests made
# 153 requests made
# 154 requests made
# 155 requests made
# 156 requests made
# 157 requests made
# 158 requests made
# 159 requests made
# 160 requests made
# 161 requests made
# 162 requests made
# 163 requests made
# 164 requests made
# 165 requests made
# 166 requests made
# 167 requests made
# 168 requests made
# 169 requests made
# 170 requests made
# 171 requests made
# 172 requests made
# 173 requests made
# 174 requests made
# 175 requests made
# 176 requests made
# 177 requests made
# 178 requests made
# 179 requests made
# 180 requests made
# 181 requests made
# 182 requests made
# 183 requests made
# 184 requests made
# 185 requests made
# 186 requests made
# 187 requests made
# 188 requests made
# 189 requests made
# 190 requests made
# 191 requests made
# 192 requests made
# 193 requests made
# 194 requests made
# 195 requests made
# 196 requests made
# 197 requests made
# 198 requests made
# 199 requests made
# 200 requests made
# 201 requests made
# 202 requests made
# 203 requests made
# 204 requests made
# 205 requests made
# 206 requests made
# 207 requests made
# 208 requests made
# 209 requests made
# 210 requests made
# 211 requests made
# 212 requests made
# 213 requests made
# 214 requests made
# 215 requests made
# 216 requests made
# 217 requests made
# 218 requests made
# 219 requests made
# 220 requests made
# 221 requests made
# 222 requests made
# 223 requests made
# 224 requests made
# 225 requests made
# 226 requests made
# 227 requests made
# 228 requests made
# 229 requests made
# 230 requests made
# 231 requests made
# 232 requests made
# 233 requests made
# 234 requests made
# 235 requests made
# 236 requests made
# 237 requests made
# 238 requests made
# 239 requests made
# 240 requests made
# 241 requests made
# 242 requests made
# 243 requests made
# 244 requests made
# 245 requests made
# 246 requests made
# 247 requests made
# unable to retrieve observation data
# 248 requests made
# 249 requests made
# 250 requests made
# 251 requests made
# 252 requests made
# 253 requests made
# 254 requests made
# 255 requests made
# 256 requests made
# 257 requests made
# 258 requests made
# 259 requests made
# 260 requests made
# 261 requests made
# 262 requests made
# 263 requests made
# 264 requests made
# 265 requests made
# 266 requests made
# 267 requests made
# 268 requests made
# 269 requests made
# 270 requests made
# 271 requests made
# 272 requests made
# 273 requests made
# 274 requests made
# 275 requests made
# 276 requests made
# 277 requests made
# 278 requests made
# 279 requests made
# 280 requests made
# 281 requests made
# 282 requests made
# 283 requests made
# 284 requests made
# 285 requests made
# 286 requests made
# 287 requests made
# 288 requests made
# 289 requests made
# 290 requests made
# 291 requests made
# 292 requests made
# 293 requests made
# 294 requests made
# 295 requests made
# 296 requests made
# 297 requests made
# 298 requests made
# 299 requests made
# 300 requests made
# 301 requests made
# 302 requests made
# 303 requests made
# 304 requests made
# 305 requests made
# 306 requests made
# 307 requests made
# 308 requests made
# 309 requests made
# 310 requests made
# 311 requests made
# 312 requests made
# 313 requests made
# 314 requests made
# 315 requests made
# 316 requests made
# 317 requests made
# 318 requests made
# 319 requests made
# 320 requests made
# 321 requests made
# 322 requests made
# 323 requests made
# 324 requests made
# 325 requests made
# 326 requests made
# 327 requests made
# 328 requests made
# 329 requests made
# 330 requests made
# 331 requests made
# 332 requests made
# 333 requests made
# 334 requests made
# 335 requests made
# 336 requests made
# 337 requests made
# 338 requests made
# 339 requests made
# 340 requests made
# 341 requests made
# 342 requests made
# 343 requests made
# 344 requests made
# 345 requests made
# 346 requests made
# 347 requests made
# 348 requests made
# 349 requests made
# 350 requests made
# 351 requests made
# 352 requests made
# 353 requests made
# 354 requests made
# 355 requests made
# 356 requests made
# 357 requests made
# 358 requests made
# 359 requests made
# 360 requests made
# 361 requests made
# 362 requests made
# 363 requests made
# 364 requests made
# 365 requests made
# 366 requests made
# 367 requests made
# 368 requests made
# 369 requests made
# 370 requests made
# 371 requests made
# 372 requests made
# 373 requests made
# 374 requests made
# 375 requests made
# 376 requests made
# 377 requests made
# 378 requests made
# 379 requests made
# 380 requests made
# 381 requests made
# 382 requests made
# 383 requests made
# 384 requests made
# 385 requests made
# 386 requests made
# 387 requests made
# 388 requests made
# 389 requests made
# 390 requests made
# 391 requests made
# 392 requests made
# 393 requests made
# 394 requests made
# 395 requests made
# 396 requests made
# 397 requests made
# 398 requests made
# 399 requests made
# 400 requests made
# 401 requests made
# 402 requests made
# 403 requests made
# 404 requests made
# 405 requests made
# 406 requests made
# 407 requests made
# 408 requests made
# 409 requests made
# 410 requests made
# 411 requests made
# 412 requests made
# 413 requests made
# 414 requests made
# 415 requests made
# 416 requests made
# 417 requests made
# 418 requests made
# 419 requests made
# 420 requests made
# 421 requests made
# 422 requests made
# 423 requests made
# 424 requests made
# 425 requests made
# 426 requests made
# 427 requests made
# 428 requests made
# 429 requests made
# 430 requests made
# 431 requests made
# 432 requests made
# 433 requests made
# 434 requests made
# 435 requests made
# 436 requests made
# 437 requests made
# 438 requests made
# 439 requests made
# 440 requests made
# 441 requests made
# 442 requests made
# 443 requests made
# 444 requests made
# 445 requests made
# 446 requests made
# 447 requests made
# 448 requests made
# 449 requests made
# 450 requests made
# 451 requests made
# 452 requests made
# 453 requests made
# 454 requests made
# 455 requests made
# 456 requests made
# 457 requests made
# 458 requests made
# 459 requests made
# 460 requests made
# 461 requests made
# 462 requests made
# 463 requests made
# 464 requests made
# 465 requests made
# 466 requests made
# 467 requests made
# 468 requests made
# 469 requests made
# 470 requests made
# 471 requests made
# 472 requests made
# 473 requests made
# 474 requests made
# 475 requests made
# 476 requests made
# 477 requests made
# 478 requests made
# 479 requests made
# 480 requests made
# 481 requests made
# 482 requests made
# 483 requests made
# 484 requests made
# 485 requests made
# 486 requests made
# 487 requests made
# 488 requests made
# 489 requests made
# 490 requests made
# 491 requests made
# 492 requests made
# 493 requests made
# 494 requests made
# 495 requests made
# 496 requests made
# 497 requests made
# 498 requests made
# 499 requests made
# 500 requests made
# 501 requests made
# 502 requests made
# 503 requests made
# 504 requests made
# 505 requests made
# 506 requests made
# 507 requests made
# 508 requests made
# 509 requests made
# 510 requests made
# 511 requests made
# 512 requests made
# 513 requests made
# 514 requests made
# 515 requests made
# 516 requests made
# 517 requests made
# 518 requests made
# 519 requests made
# 520 requests made
# 521 requests made
# 522 requests made
# 523 requests made
# 524 requests made
# 525 requests made
# 526 requests made
# 527 requests made
# 528 requests made
# 529 requests made
# 530 requests made
# 531 requests made
# 532 requests made
# 533 requests made
# 534 requests made
# 535 requests made
# 536 requests made
# 537 requests made
# 538 requests made
# 539 requests made
# 540 requests made
# 541 requests made
# 542 requests made
# 543 requests made
# 544 requests made
# 545 requests made
# 546 requests made
# 547 requests made
# 548 requests made
# 549 requests made
# 550 requests made
# 551 requests made
# 552 requests made
# 553 requests made
# 554 requests made
# 555 requests made
# 556 requests made
# 557 requests made
# 558 requests made
# 559 requests made
# 560 requests made
# 561 requests made
# 562 requests made
# 563 requests made
# 564 requests made
# 565 requests made
# 566 requests made
# 567 requests made
# 568 requests made
# 569 requests made
# 570 requests made
# 571 requests made
# 572 requests made
# 573 requests made
# 574 requests made
# 575 requests made
# 576 requests made
# 577 requests made
# 578 requests made
# 579 requests made
# 580 requests made
# 581 requests made
# unable to retrieve observation data
# 582 requests made
# 583 requests made
# 584 requests made
# 585 requests made
# 586 requests made
# 587 requests made
# 588 requests made
# 589 requests made
# 590 requests made
# 591 requests made
# 592 requests made
# 593 requests made
# 594 requests made
# 595 requests made
# 596 requests made
# 597 requests made
# 598 requests made
# 599 requests made
# 600 requests made
# 601 requests made
# 602 requests made
# 603 requests made
# 604 requests made
# 605 requests made
# 606 requests made
# 607 requests made
# 608 requests made
# 609 requests made
# 610 requests made
# 611 requests made
# 612 requests made
# 613 requests made
# 614 requests made
# 615 requests made
# 616 requests made
# 617 requests made
# 618 requests made
# 619 requests made
# 620 requests made
# 621 requests made
# 622 requests made
# 623 requests made
# 624 requests made
# 625 requests made
# 626 requests made
# 627 requests made
# 628 requests made
# 629 requests made
# 630 requests made
# 631 requests made
# 632 requests made
# 633 requests made
# 634 requests made
# 635 requests made
# 636 requests made
# 637 requests made
# 638 requests made
# 639 requests made
# 640 requests made
# 641 requests made
# 642 requests made
# 643 requests made
# 644 requests made
# 645 requests made
# 646 requests made
# 647 requests made
# 648 requests made
# 649 requests made
# 650 requests made
# 651 requests made
# 652 requests made
# 653 requests made
# 654 requests made
# 655 requests made
# 656 requests made
# 657 requests made
# 658 requests made
# 659 requests made
# 660 requests made
# 661 requests made
# 662 requests made
# 663 requests made
# 664 requests made
# 665 requests made
# 666 requests made
# 667 requests made
# 668 requests made
# 669 requests made
# 670 requests made
# 671 requests made
# 672 requests made
# 673 requests made
# 674 requests made
# 675 requests made
# 676 requests made
# 677 requests made
# 678 requests made
# 679 requests made
# 680 requests made
# 681 requests made
# 682 requests made
# 683 requests made
# 684 requests made
# 685 requests made
# 686 requests made
# 687 requests made
# 688 requests made
# 689 requests made
# 690 requests made
# 691 requests made
# 692 requests made
# 693 requests made
# 694 requests made
# 695 requests made
# 696 requests made
# 697 requests made
# 698 requests made
# 699 requests made
# 700 requests made
# 701 requests made
# 702 requests made
# 703 requests made
# 704 requests made
# 705 requests made
# 706 requests made
# 707 requests made
# 708 requests made
# 709 requests made
# 710 requests made
# 711 requests made
# 712 requests made
# 713 requests made
# 714 requests made
# 715 requests made
# 716 requests made
# 717 requests made
# 718 requests made
# 719 requests made
# 720 requests made
# 721 requests made
# 722 requests made
# 723 requests made
# 724 requests made
# 725 requests made
# 726 requests made
# 727 requests made
# 728 requests made
# 729 requests made
# 730 requests made
# 731 requests made
# 732 requests made
# 733 requests made
# 734 requests made
# 735 requests made
# 736 requests made
# 737 requests made
# 738 requests made
# 739 requests made
# 740 requests made
# 741 requests made
# 742 requests made
# 743 requests made
# 744 requests made
# 745 requests made
# 746 requests made
# 747 requests made
# 748 requests made
# 749 requests made
# 750 requests made
# 751 requests made
# 752 requests made
# 753 requests made
# 754 requests made
# 755 requests made
# 756 requests made
# 757 requests made
# 758 requests made
# 759 requests made
# 760 requests made
# 761 requests made
# 762 requests made
# 763 requests made
# 764 requests made
# 765 requests made
# 766 requests made
# 767 requests made
# 768 requests made
# 769 requests made
# 770 requests made
# 771 requests made
# 772 requests made
# 773 requests made
# 774 requests made
# 775 requests made
# 776 requests made
# 777 requests made
# 778 requests made
# unable to retrieve observation data
# 779 requests made
# 780 requests made
# 781 requests made
# 782 requests made
# 783 requests made
# unable to retrieve observation data
# 784 requests made
# 785 requests made
# 786 requests made
# 787 requests made
# 788 requests made
# 789 requests made
# 790 requests made
# 791 requests made
# 792 requests made
# 793 requests made
# 794 requests made
# 795 requests made
# 796 requests made
# 797 requests made
# 798 requests made
# unable to retrieve observation data
# 799 requests made
# 800 requests made
# 801 requests made
# 802 requests made
# 803 requests made
# 804 requests made
# 805 requests made
# 806 requests made
# 807 requests made
# unable to retrieve observation data
# 808 requests made
# 809 requests made
# 810 requests made
# 811 requests made
# 812 requests made
# 813 requests made
# 814 requests made
# 815 requests made
# 816 requests made
# 817 requests made
# 818 requests made
# unable to retrieve observation data
# 819 requests made
# 820 requests made
# 821 requests made
# 822 requests made
# 823 requests made
# 824 requests made
# 825 requests made
# 826 requests made
# 827 requests made
# 828 requests made
# 829 requests made
# 830 requests made
# 831 requests made
# 832 requests made
# 833 requests made
# 834 requests made
# 835 requests made
# 836 requests made
# 837 requests made
# 838 requests made
# 839 requests made
# 840 requests made
# 841 requests made
# 842 requests made
# 843 requests made
# 844 requests made
# 845 requests made
# 846 requests made
# 847 requests made
# 848 requests made
# 849 requests made
# 850 requests made
# 851 requests made
# 852 requests made
# 853 requests made
# 854 requests made
# 855 requests made
# 856 requests made
# 857 requests made
# 858 requests made
# 859 requests made
# 860 requests made
# 861 requests made
# 862 requests made
# 863 requests made
# 864 requests made
# 865 requests made
# 866 requests made
# 867 requests made
# 868 requests made
# 869 requests made
# 870 requests made
# 871 requests made
# 872 requests made
# 873 requests made
# 874 requests made
# 875 requests made
# 876 requests made
# 877 requests made
# 878 requests made
# 879 requests made
# 880 requests made
# 881 requests made
# 882 requests made
# 883 requests made
# 884 requests made
# 885 requests made
# 886 requests made
# 887 requests made
# 888 requests made
# 889 requests made
# 890 requests made
# 891 requests made
# 892 requests made
# 893 requests made
# 894 requests made
# 895 requests made
# 896 requests made
# 897 requests made
# 898 requests made
# 899 requests made
# 900 requests made

# %%
gdf_raw = gpd.GeoDataFrame(data=office_data)
gdf_dropna = gdf_raw.dropna(subset=['grid_id', 'grid_x', 'grid_y'])
gdf_clean = gdf_dropna.drop_duplicates()
len(gdf_clean)
# Out:
# 891

# %%
from pyproj import Transformer, CRS
from shapely.geometry import Point
from shapely.ops import transform

def make_buffer(coordinates):

    aeqd_crs = CRS.from_proj4(f"+proj=aeqd +lat_0={lat} +lon_0={lon} +datum=WGS84")
    to_4326 = Transformer.from_crs(aeqd_crs, 4326, always_xy=True).transform
    to_aeqd = Transformer.from_crs(4326, aeqd_crs, always_xy=True).transform

    buffer_center = transform(to_aeqd, coordinates)
    buffer_aeqd = buffer_center.buffer(100000)  # 100 km
    buffer_4326 = transform(to_4326, buffer_aeqd)
    
    return gpd.GeoDataFrame(data={'geometry' : [buffer_4326]}, crs='EPSG:4326')

# %%
TEST_COORDS = Point(-107.9, 37.2)

buffer = make_buffer(TEST_COORDS)
forecastOffices = gdf_clean.set_crs('EPSG:4326')
points_within_buffer = gpd.sjoin(forecastOffices, buffer, how='inner', predicate='within')
points_within_buffer
# Out:
#                         geometry  grid_x  grid_y grid_id  \
# 252  POINT (-108.21864 36.65377)      45     185     ABQ
# 281  POINT (-108.69941 36.79049)      31     205     ABQ
# 282  POINT (-108.34571 36.74873)      47     204     ABQ
# 283  POINT (-107.81419 36.73616)      62     202     ABQ
# 284  POINT (-107.49308 36.99341)      77     201     ABQ
# 285  POINT (-106.93537 36.93277)      92     199     ABQ
# 311  POINT (-108.72646 37.21260)      81      21     GJT
# 312  POINT (-108.29386 37.34660)      96      19     GJT
# 313  POINT (-107.86892 37.27672)     112      18     GJT
# 314  POINT (-107.59481 37.23525)     127      16     GJT
# 315  POINT (-107.00353 37.26360)     142      15     GJT
# 316  POINT (-107.00353 37.26360)      22      25     PUB
# 341  POINT (-108.66006 37.50171)      83      39     GJT
# 342  POINT (-108.03143 37.68857)      98      38     GJT
# 343  POINT (-108.03143 37.68857)     113      36     GJT
# 344  POINT (-107.66464 37.81109)     129      35     GJT
#
#                                 original_point  index_right
# 252   (36.41034482758621, -108.28620689655172)            0
# 281  (36.824137931034485, -108.71379310344828)            0
# 282  (36.824137931034485, -108.28620689655172)            0
# 283  (36.824137931034485, -107.85862068965517)            0
# 284  (36.824137931034485, -107.43103448275862)            0
# 285  (36.824137931034485, -107.00344827586207)            0
# 311   (37.23793103448276, -108.71379310344828)            0
# 312   (37.23793103448276, -108.28620689655172)            0
# 313   (37.23793103448276, -107.85862068965517)            0
# 314   (37.23793103448276, -107.43103448275862)            0
# 315   (37.23793103448276, -107.00344827586207)            0
# 316   (37.23793103448276, -106.57586206896552)            0
# 341   (37.65172413793103, -108.71379310344828)            0
# 342   (37.65172413793103, -108.28620689655172)            0
# 343   (37.65172413793103, -107.85862068965517)            0
# 344   (37.65172413793103, -107.43103448275862)            0

# %%
import statistics


DESIRED_WEATHER = 70

points_within_buffer['mean_temp'] = np.nan
points_within_buffer['desired_temp_diff'] = np.nan

for idx, row in points_within_buffer.iterrows():
    print("Requesting", row['grid_x'], row['grid_y'], row['grid_id'])
    response_raw = requests.get(f"https://api.weather.gov/gridpoints/{row['grid_id']}/{row['grid_x']},{row['grid_y']}/forecast/hourly")
    if response_raw.status_code == 200:
        response = response_raw.json()
        periods = response['properties']['periods']
        ave_temps = statistics.mean([period['temperature'] for period in periods if 1 <= period['number'] <= 48])
        points_within_buffer.at[idx, 'mean_temp'] = ave_temps
        points_within_buffer.at[idx, 'desired_temp_diff'] = abs(ave_temps - DESIRED_WEATHER)

destinations_sorted = points_within_buffer.sort_values('desired_temp_diff')      
destinations_sorted
# Out:
# Requesting 45 185 ABQ
# Requesting 31 205 ABQ
# Requesting 47 204 ABQ
# Requesting 62 202 ABQ
# Requesting 77 201 ABQ
# Requesting 92 199 ABQ
# Requesting 81 21 GJT
# Requesting 96 19 GJT
# Requesting 112 18 GJT
# Requesting 127 16 GJT
# Requesting 142 15 GJT
# Requesting 22 25 PUB
# Requesting 83 39 GJT
# Requesting 98 38 GJT
# Requesting 113 36 GJT
# Requesting 129 35 GJT
#                         geometry  grid_x  grid_y grid_id  \
# 252  POINT (-108.21864 36.65377)      45     185     ABQ
# 282  POINT (-108.34571 36.74873)      47     204     ABQ
# 281  POINT (-108.69941 36.79049)      31     205     ABQ
# 283  POINT (-107.81419 36.73616)      62     202     ABQ
# 311  POINT (-108.72646 37.21260)      81      21     GJT
# 284  POINT (-107.49308 36.99341)      77     201     ABQ
# 312  POINT (-108.29386 37.34660)      96      19     GJT
# 314  POINT (-107.59481 37.23525)     127      16     GJT
# 341  POINT (-108.66006 37.50171)      83      39     GJT
# 313  POINT (-107.86892 37.27672)     112      18     GJT
# 285  POINT (-106.93537 36.93277)      92     199     ABQ
# 315  POINT (-107.00353 37.26360)     142      15     GJT
# 342  POINT (-108.03143 37.68857)      98      38     GJT
# 343  POINT (-108.03143 37.68857)     113      36     GJT
# 316  POINT (-107.00353 37.26360)      22      25     PUB
# 344  POINT (-107.66464 37.81109)     129      35     GJT
#
#                                 original_point  index_right  mean_temp  \
# 252   (36.41034482758621, -108.28620689655172)            0  51.020833
# 282  (36.824137931034485, -108.28620689655172)            0  50.437500
# 281  (36.824137931034485, -108.71379310344828)            0  50.229167
# 283  (36.824137931034485, -107.85862068965517)            0  49.958333
# 311   (37.23793103448276, -108.71379310344828)            0  49.104167
# 284  (36.824137931034485, -107.43103448275862)            0  49.000000
# 312   (37.23793103448276, -108.28620689655172)            0  48.895833
# 314   (37.23793103448276, -107.43103448275862)            0  47.875000
# 341   (37.65172413793103, -108.71379310344828)            0  47.500000
# 313   (37.23793103448276, -107.85862068965517)            0  46.708333
# 285  (36.824137931034485, -107.00344827586207)            0  44.291667
# 315   (37.23793103448276, -107.00344827586207)            0  43.479167
# 342   (37.65172413793103, -108.28620689655172)            0  39.062500
# 343   (37.65172413793103, -107.85862068965517)            0  35.916667
# 316   (37.23793103448276, -106.57586206896552)            0  29.041667
# 344   (37.65172413793103, -107.43103448275862)            0  25.437500
#
#      desired_temp_diff
# 252          18.979167
# 282          19.562500
# 281          19.770833
# 283          20.041667
# 311          20.895833
# 284          21.000000
# 312          21.104167
# 314          22.125000
# 341          22.500000
# 313          23.291667
# 285          25.708333
# 315          26.520833
# 342          30.937500
# 343          34.083333
# 316          40.958333
# 344          44.562500

# %%
# Create base map centered on your points
m2 = folium.Map(location=[points_within_buffer.geometry.y.mean(), points_within_buffer.geometry.x.mean()], zoom_start=6)


colors=['blue', 'red']

# Loop through each point
for idx, row in points_within_buffer.iterrows():
    folium.Marker(
        location=[row.geometry.y, row.geometry.x],
        popup=f"Mean Temp: {row['mean_temp']:.1f}°F",
        icon=folium.Icon(color=colors[0] if row['mean_temp'] < 47 else colors[1], icon='cloud')
    ).add_to(m2)

m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_717fa390d9840ff475e5a49a530e8d85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_717fa390d9840ff475e5a49a530e8d85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_717fa390d9840ff475e5a49a530e8d85 = L.map(
#                 &quot;map_717fa390d9840ff475e5a49a530e8d85&quot;,
#                 {
#                     center: [37.19647781250001, -107.899066375],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6fc38446eb164240a5cf46ed3a0c8400 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6fc38446eb164240a5cf46ed3a0c8400.addTo(map_717fa390d9840ff475e5a49a530e8d85);
#
#
#             var marker_cec900819c40db564e064e34330784c7 = L.marker(
#                 [36.653774, -108.218639],
#                 {}
#             ).addTo(map_717fa390d9840ff475e5a49a530e8d85);
#
#
#             var icon_19c968557e93105f667fd2481d431249 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cec900819c40db564e064e34330784c7.setIcon(icon_19c968557e93105f667fd2481d431249);
#
#
#         var popup_b19cdb46a792073ae613c406a458c86c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5893cbf3b7d468f893f8e4ba422fcfd1 = $(`&lt;div id=&quot;html_5893cbf3b7d468f893f8e4ba422fcfd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mean Temp: 51.0°F&lt;/div&gt;`)[0];
#                 popup_b19cdb46a792073ae613c406a458c86c.setContent(html_5893cbf3b7d468f893f8e4ba422fcfd1);
#
#
#
#         marker_cec900819c40db564e064e34330784c7.bindPopup(popup_b19cdb46a792073ae613c406a458c86c)
#         ;
#
#
#
#
#             var marker_2a9e90a8fc3f38495644127c39b338b2 = L.marker(
#                 [36.790491, -108.699407],
#                 {}
#             ).addTo(map_717fa390d9840ff475e5a49a530e8d85);
#
#
#             var icon_f67d7c7fd88e043daa78d9520aa31448 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2a9e90a8fc3f38495644127c39b338b2.setIcon(icon_f67d7c7fd88e043daa78d9520aa31448);
#
#
#         var popup_2d6a7a2630cb217496b5ec24e4653d81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c418d40442f229a46f1f3f8048c91f0 = $(`&lt;div id=&quot;html_2c418d40442f229a46f1f3f8048c91f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mean Temp: 50.2°F&lt;/div&gt;`)[0];
#                 popup_2d6a7a2630cb217496b5ec24e4653d81.setContent(html_2c418d40442f229a46f1f3f8048c91f0);
#
#
#
#         marker_2a9e90a8fc3f38495644127c39b338b2.bindPopup(popup_2d6a7a2630cb217496b5ec24e4653d81)
#         ;
#
#
#
#
#             var marker_aa354c371715127a17fbc12e497255df = L.marker(
#                 [36.748725, -108.345707],
#                 {}
#             ).addTo(map_717fa390d9840ff475e5a49a530e8d85);
#
#
#             var icon_519bd22fc030ede31a502681ec32faf9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_aa354c371715127a17fbc12e497255df.setIcon(icon_519bd22fc030ede31a502681ec32faf9);
#
#
#         var popup_6953a88ed90601dd5f13f090068f4e59 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0590e1b1ab7b26fe47042c72f0002b5c = $(`&lt;div id=&quot;html_0590e1b1ab7b26fe47042c72f0002b5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mean Temp: 50.4°F&lt;/div&gt;`)[0];
#                 popup_6953a88ed90601dd5f13f090068f4e59.setContent(html_0590e1b1ab7b26fe47042c72f0002b5c);
#
#
#
#         marker_aa354c371715127a17fbc12e497255df.bindPopup(popup_6953a88ed90601dd5f13f090068f4e59)
#         ;
#
#
#
#
#             var marker_9837345f556781ae8fdc55b6c6da5e98 = L.marker(
#                 [36.736156, -107.814191],
#                 {}
#             ).addTo(map_717fa390d9840ff475e5a49a530e8d85);
#
#
#             var icon_e3a7ec158291e7d6211257b6427fffa0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;whit
